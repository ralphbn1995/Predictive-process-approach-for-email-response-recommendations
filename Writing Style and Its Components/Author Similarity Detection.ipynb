# %% [markdown]
# # Authorship Similarity Detection

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import pandas as pd
import numpy as np

#Graphics
import seaborn as sns
import matplotlib.pyplot as plt

#Preprocessing 
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk import SnowballStemmer

#ML
import sklearn
from sklearn import metrics as mt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import MaxAbsScaler
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import  RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier 


#Utils
import os
import string
from collections import Counter
import joblib
import pickle
from itertools import compress
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rbnra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rbnra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def RandomizedSearch_table_plot(grid_clf, param_list=[],
                          num_results=40,
                          negative=True,
                          graph=True,
                          display_all_params=True):

  
    from matplotlib      import pyplot as plt
    from IPython.display import display
    import pandas as pd

    clf = grid_clf.best_estimator_
    clf_params = grid_clf.best_params_
    if negative:
        clf_score = -grid_clf.best_score_
    else:
        clf_score = grid_clf.best_score_
    clf_stdev = grid_clf.cv_results_['std_test_score'][grid_clf.best_index_]
    cv_results = grid_clf.cv_results_

    print("best parameters: {}".format(clf_params))
    print("best score:      {:0.5f} (+/-{:0.5f})".format(clf_score, clf_stdev))
    #if display_all_params:
     #   import pprint
      #  pprint.pprint(clf.get_params())

    # pick out the best results
    # =========================
    scores_df = pd.DataFrame(cv_results).sort_values(by='rank_test_score')
    import uuid
      
    scores_df.to_pickle(str(uuid.uuid4())+"file.pkl")
    best_row = scores_df.iloc[0, :]
    if negative:
        best_mean = -best_row['mean_test_score']
    else:
        best_mean = best_row['mean_test_score']
    best_stdev = best_row['std_test_score']
    #best_param = best_row['param_' + param_name]

    # display the top 'num_results' results
    # =====================================
    table=pd.DataFrame(cv_results)
    del table['split0_test_score']
    del table['split1_test_score']
    del table['split2_test_score']
    del table['split3_test_score']
    del table['split4_test_score']
    del table['split0_train_score']
    del table['split1_train_score']
    del table['split2_train_score']
    del table['split3_train_score']
    del table['split4_train_score']
    del table['mean_fit_time']
    del table['std_fit_time']
    del table['mean_score_time']	
    del table['std_score_time']
    del table['params']
    display(table \
            .sort_values(by='rank_test_score').head(num_results))

    # plot the results
    # ================
    scores_df = scores_df.sort_values(by='rank_test_score')
    #print(scores_df.keys())
    for param_name in param_list:
        scores_df = scores_df.sort_values(by='param_' + param_name)
        best_param = best_row['param_' + param_name]
        
        if negative:
            means = -scores_df['mean_test_score']
        else:
            means = scores_df['mean_test_score']
        stds = scores_df['std_test_score']
        params = scores_df['param_' + param_name]
        params.fillna(1400, inplace=True)
        #params = [str(i) for i in params]
        # plot
        if graph:
            plt.figure(figsize=(4, 4))
            plt.plot(params, means,"o")

            plt.axhline(y=best_mean + best_stdev, color='red')
            plt.axhline(y=best_mean - best_stdev, color='red')
            plt.plot(best_param, best_mean, 'or')

            plt.title(param_name + " vs Score\nBest Score {:0.5f}".format(clf_score))
            plt.xlabel(param_name)
            plt.ylabel('Score')
    plt.show()
  
#Selection of the best number of components for TruncatedSVD
def select_n_components(var_ratio, goal_var: float) -> int:
    total_variance = 0.0

    n_components = 0
    
    for explained_variance in var_ratio:
    
        total_variance += explained_variance
        
        n_components += 1
        
        if total_variance >= goal_var:
            break
            
    return n_components


def show_results(labels, predictions):
    print( "Accuracy: ", accuracy_score(labels, predictions))
    print("Avg Precision", precision_score(labels, predictions, average='weighted')) 
    print("Avg Recall",recall_score(labels, predictions, average='weighted')) 
    print("Avg F1-score",f1_score(labels, predictions, average='weighted')) 


#Function that displays histogram between models based on accuracy
def plot_glob_accuracy(model_names,list_accuracy):
    if(len(model_names) == 2):
        y_pos = np.arange(1,3)
        colors = ("teal","mediumturquoise")
        plt.figure(figsize=(8,5))
        plt.xticks(y_pos,model_names,fontsize=14)
        plt.yticks(np.arange(0.00, 1.01, step=0.1))
        plt.ylim(0,1)
        plt.ylabel('Accuracy')
        plt.bar(y_pos,list_accuracy,color=colors)
        plt.grid()
        plt.show()
    else:
        y_pos = np.arange(1,4)
        colors = ("teal","mediumturquoise","mediumaquamarine")
        plt.figure(figsize=(15,5))
        plt.xticks(y_pos,model_names,fontsize=14)
        plt.yticks(np.arange(0.00, 1.01, step=0.1))
        plt.ylim(0,1)
        plt.ylabel('Accuracy')
        plt.bar(y_pos,list_accuracy,color=colors)
        plt.grid()
        plt.show()

             
def plot_glob_f1score(model_names,list_f1score):
    if(len(model_names) == 2):
        y_pos = np.arange(1,3)
        colors = ("purple","darkorchid")
        plt.figure(figsize=(8,5))
        plt.xticks(y_pos,model_names,fontsize=14)
        plt.yticks(np.arange(0.00, 1.01, step=0.1))
        plt.ylim(0,1)
        plt.ylabel('F1 score')
        plt.bar(y_pos,list_f1score,color=colors)
        plt.grid()
        plt.show()
    else:
        y_pos = np.arange(1,4)
        colors = ("purple","darkorchid", "orchid")
        plt.figure(figsize=(15,5))
        plt.xticks(y_pos,model_names,fontsize=14)
        plt.yticks(np.arange(0.00, 1.01, step=0.1))
        plt.ylim(0,1)
        plt.ylabel('F1 score')
        plt.bar(y_pos,list_f1score,color=colors)
        plt.grid()
        plt.show()

# %% [markdown]
# # Dataset loading and structure analysis

# %%
dataset = pd.read_csv("../Data/writing_style_dataset.csv", sep = '*')
import itertools
replacements = dict(zip(dataset['author'].unique(),itertools.count(1)))
dataset["author"] = dataset["author"].replace(replacements)

# %%
dataset.head()
# Out:
#                                                 text  author
# 0  According to Vance s response to Lauri s email...       1
# 1  Effective 3 1 2001 HPLC amended its contract w...       2
# 2  Louis Cox with Copano the interconnecting part...       3
# 3  X cc Weissman George O ENRON OU NA CN RECIPIEN...       4
# 4  I m still concern about April s nom if we don ...       4

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    638 non-null    object
#  1   author  638 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 10.1+ KB

# %%
authors_list = list(dict.fromkeys(dataset['author'].values))
print("Total number of authors:", len(authors_list))
# Out:
# Numero totale di autori: 97

# %%
print(Counter(list(dataset['author'].values)))
g =sns.catplot(x="author", kind="count", palette="ch:.25", data=dataset)
g.fig.set_size_inches(17, 5)
g.ax.set_title('Distribuition of classes', fontsize=20)
# Out:
# Counter({30: 260, 40: 45, 8: 44, 16: 18, 2: 13, 1: 12, 37: 12, 5: 11, 31: 9, 86: 8, 7: 7, 13: 7, 18: 7, 41: 6, 60: 6, 28: 5, 36: 5, 42: 5, 73: 5, 81: 5, 6: 4, 17: 4, 22: 4, 39: 4, 54: 4, 61: 4, 80: 4, 87: 4, 88: 4, 96: 4, 3: 3, 10: 3, 15: 3, 27: 3, 32: 3, 43: 3, 56: 3, 59: 3, 67: 3, 69: 3, 76: 3, 82: 3, 95: 3, 4: 2, 9: 2, 19: 2, 21: 2, 23: 2, 33: 2, 34: 2, 46: 2, 64: 2, 72: 2, 79: 2, 84: 2, 85: 2, 89: 2, 90: 2, 11: 1, 12: 1, 14: 1, 20: 1, 24: 1, 25: 1, 26: 1, 29: 1, 35: 1, 38: 1, 44: 1, 45: 1, 47: 1, 48: 1, 49: 1, 50: 1, 51: 1, 52: 1, 53: 1, 55: 1, 57: 1, 58: 1, 62: 1, 63: 1, 65: 1, 66: 1, 68: 1, 70: 1, 71: 1, 74: 1, 75: 1, 77: 1, 78: 1, 83: 1, 91: 1, 92: 1, 93: 1, 94: 1, 97: 1})
# Text(0.5, 1.0, 'Distribuition of classes')

# %%
prova = dataset.loc[1]
prova.text[:500]+"..."
# Out:
# 'Effective 3 1 2001 HPLC amended its contract with Royal Production changing the price to 100 HSC less 0 16 and extending the term through 2 28 02 Consequently for March HPLC should be purhasing volumes from two wells at meter 5310 Effective April HPLC amended the same contract releasing the L G Talbert 2 lease in the committed reserves agreement Mike Morris is the gas buyer and expects volumes of approximately 2000mmbtu d For April I nom 1132 d Bob we should probably increase the nom to reflect ...'

# %% [markdown]
# # Preprocessing

# %%
dataset.isnull().sum()
# Out:
# text      0
# author    0
# dtype: int64

# %%
customized_list = ["â","a", "b", "c", "d", "e","f","g","h","l", "m", "n", "o", "p","q", "r", "s","t","u","v","w","z", "y", "j","k", "ah", "eh", "uh", "ahi", "oh", "ow", "ew", "aw"]
stopword_list = stopwords.words('english')+ list(string.punctuation) + customized_list

# %%
dataset_tokenized = dataset.copy()

for row in dataset_tokenized.itertuples():
    dataset_tokenized.at[row.Index, "text"]= word_tokenize(row.text)

for row in dataset_tokenized.itertuples():
    novel = [token for token in dataset_tokenized.at[row.Index, "text"] if token not in stopword_list]
    dataset_tokenized.at[row.Index, "text"]= novel

stemmer = SnowballStemmer(language='english')

for row in dataset_tokenized.itertuples():
    novel = [stemmer.stem(token) for token in row.text]
    dataset_tokenized.at[row.Index, "text"]= novel

#save tokenized dataset on drive
dataset_tokenized.to_pickle("../Data/data_tokenized.csv")

# %% [markdown]
# # Split in Test and Traning set

# %%
labels_list = dataset_tokenized["author"]
X_train, X_test, y_train, y_test = train_test_split(dataset_tokenized, labels_list, test_size=0.3, random_state=1)
X_train
# Out:
#                                                   text  author
# 118  [as, discuss, earlier, i, propos, ramp, late, ...      30
# 4    [i, still, concern, april, nom, take, zero, co...       4
# 428  [i, think, saturday, morn, come, strong, get, ...      30
# 531  [ena, invoic, coral, energi, two, deal, teja, ...      16
# 530  [i, see, new, path, desk, desk, nov, 2000, you...      16
# ..                                                 ...     ...
# 129  [x, to, capasso, joe, o, enron, ou, na, cn, re...      30
# 144  [in, refer, eterra, i, priorit, enhanc, system...      36
# 72   [this, deal, equistar, there, enough, gas, met...      21
# 235  [this, mail, properti, enron, corp, relev, aff...      55
# 37   [want, share, latest, communic, netco, this, g...      13
#
# [446 rows x 2 columns]

# %%
corpus_train = []
n_docs = len(X_train['text'])
for i in range(0, n_docs-1):
    corpus_train = corpus_train + X_train['text'].iloc[i]

# %%
# We concatenate all the texts of each author into a list of tokens and create a dictionary to hold the documents of each authortokens_authors = dict.fromkeys(authors_list,[])
for i in authors_list:
    docs_auth = [item[0] for item in X_train.loc[X_train.author == i].values]
    tokens_authors[i] =(docs_auth)
print(tokens_authors)
# Out:
# {1: [['x', 'to', 'robert', 'cotten', 'jacki', 'young', 'charlott', 'hawkin', 'carlo', 'j', 'rodriguez', 'stella', 'l', 'morri', 'aime', 'lannou', 'georg', 'grant', 'sabra', 'zajac', 'ricki', 'elli', 'tom', 'acton', 'mark', 'mccoy', 'eddi', 'janzen'], ['x', 'cc', 'gari', 'a', 'hank', 'angela', 'henn', 'howard', 'b', 'camp', 'lee', 'l', 'papayoti', 'daren', 'j', 'farmer', 'gari', 'w', 'lamphier', 'david', 'baumbach', 'lisa', 'csiko', 'joani', 'h', 'ngo', 'jennif', 'blay', 'pat', 'clyne'], ['x', 'cc', 'daren', 'j', 'farmer', 'daren', 'j', 'farmer', 'hou', 'ect', 'ect', 'edward', 'terri', 'edward', 'terri', 'hou', 'ect', 'ect', 'clem', 'cernosek', 'clem', 'cernosek', 'hou', 'ect', 'ect', 'juli', 'meyer', 'juli', 'meyer', 'hou', 'ect', 'ect', 'cynthia', 'hakemack', 'cynthia', 'hakemack', 'hou', 'ect', 'ect', 'melissa', 'grave', 'melissa', 'grave', 'hou', 'ect', 'ect', 'susan', 'smith', 'susan', 'smith', 'hou', 'ect', 'ect', 'donald', 'p', 'reinhardt', 'donald', 'p', 'reinhardt', 'hou', 'ect', 'ect'], ['x', 'to', 'mandi', 'mackinnon', 'georg', 'grant', 'aime', 'lannou', 'jacki', 'young', 'susan', 'd', 'trevino', 'stella', 'l', 'morri', 'kimber', 'vaughn', 'charlott', 'hawkin', 'carlo', 'j', 'rodriguez', 'tom', 'acton'], ['mike', 'gas', 'control', 'call', 'said', 'meter', '9842', 'flood', 'flow', 'coupl', 'day', 'the', 'field', 'tech', 'said', 'probabl', 'day', 'resum', 'do', 'want', 'nom', 'adjust', 'it', '8', '034', 'the', 'deal', '377169'], ['cc', 'juli', 'meyer', 'hou', 'ect', 'ect', 'lisa', 'hess', 'hou', 'ect', 'ect', 'cynthia', 'hakemack', 'hou', 'ect', 'ect', 'donald', 'p', 'reinhardt', 'enron', 'enronxg', 'enron', 'susan', 'smith', 'enron', 'enronxg', 'enron', 'melissa', 'grave', 'enron', 'enronxg', 'enron'], ['x', 'cc', 'daren', 'j', 'farmer', 'melissa', 'grave', 'o', 'neal', 'd', 'winfre', 'jennif', 'blay', 'lisa', 'hess', 'trisha', 'hugh', 'susan', 'smith', 'donald', 'p', 'reinhardt', 'melissa', 'grave', 'tom', 'acton'], ['x', 'cc', 'brian', 'm', 'riley', 'daren', 'j', 'farmer', 'melissa', 'grave', 'clem', 'cernosek', 'mari', 'poorman', 'anita', 'luong', 'donald', 'p', 'reinhardt', 'cynthia', 'hakemack', 'juli', 'meyer', 'lisa', 'hess']], 2: [['fyi', 'creat', 'submit', 'commit', 'reserv', 'firm', 'ticket', 'remain', 'term', 'deal', 'begin', 'appropi', 'month', 'addit', 'produc', 'svcs', 'deal', 'track', 'im', 'wellhead', 'portfolio', 'attach', 'gather', 'contract'], ['fyi', 'creat', 'submit', 'commit', 'reserv', 'firm', 'ticket', 'remain', 'term', 'deal', 'begin', 'appropi', 'month', 'addit', 'produc', 'svcs', 'deal', 'track', 'im', 'wellhead', 'portfolio', 'attach', 'gather', 'contract'], ['cc', 'juli', 'meyer', 'hou', 'ect', 'ect', 'lisa', 'hess', 'hou', 'ect', 'ect', 'cynthia', 'hakemack', 'hou', 'ect', 'ect', 'donald', 'p', 'reinhardt', 'enron', 'enronxg', 'susan', 'smith', 'enron', 'enronxg', 'melissa', 'grave', 'enron', 'enronxg'], ['effect', '3', '1', '2001', 'hplc', 'amend', 'contract', 'royal', 'product', 'chang', 'price', '100', 'hsc', 'less', '0', '16', 'extend', 'term', '2', '28', '02', 'consequ', 'march', 'hplc', 'purhas', 'volum', 'two', 'well', 'meter', '5310', 'effect', 'april', 'hplc', 'amend', 'contract', 'releas', 'l', 'g', 'talbert', '2', 'leas', 'commit', 'reserv', 'agreement', 'mike', 'morri', 'gas', 'buyer', 'expect', 'volum', 'approxim', '2000mmbtu', 'for', 'april', 'i', 'nom', '1132', 'bob', 'probabl', 'increas', 'nom', 'reflect', 'increment', 'product', 'point'], ['fyi', 'i', 'creat', 'submit', 'commit', 'reserv', 'firm', 'ticket', 'remain', 'term', 'deal', 'begin', 'month', 'april', 'addit', 'produc', 'svcs', 'deal', 'track', 'im', 'wellhead', 'portfolio', 'attach', 'gather', 'contract'], ['cc', 'brian', 'm', 'riley', 'hou', 'ect', 'ect', 'susan', 'smith', 'enron', 'enronxg', 'donald', 'p', 'reinhardt', 'enron', 'enronxg', 'melissa', 'grave', 'enron', 'enronxg', 'georg', 'weissman', 'hou', 'ect', 'ect'], ['hplc', 'purchas', 'wellhead', 'gas', 'produc', 'list', 'product', 'month', 'may', '2001',  ...

# %%
#frequencies of terms used by each author
word_frequencies = dict.fromkeys(authors_list,[])

for author in authors_list:
    if (tokens_authors[author]):
        word_frequencies[author] = Counter(tokens_authors[author][0]).most_common()
    
    print(word_frequencies[author])
# Out:
# [('x', 1), ('to', 1), ('robert', 1), ('cotten', 1), ('jacki', 1), ('young', 1), ('charlott', 1), ('hawkin', 1), ('carlo', 1), ('j', 1), ('rodriguez', 1), ('stella', 1), ('l', 1), ('morri', 1), ('aime', 1), ('lannou', 1), ('georg', 1), ('grant', 1), ('sabra', 1), ('zajac', 1), ('ricki', 1), ('elli', 1), ('tom', 1), ('acton', 1), ('mark', 1), ('mccoy', 1), ('eddi', 1), ('janzen', 1)]
# [('deal', 2), ('fyi', 1), ('creat', 1), ('submit', 1), ('commit', 1), ('reserv', 1), ('firm', 1), ('ticket', 1), ('remain', 1), ('term', 1), ('begin', 1), ('appropi', 1), ('month', 1), ('addit', 1), ('produc', 1), ('svcs', 1), ('track', 1), ('im', 1), ('wellhead', 1), ('portfolio', 1), ('attach', 1), ('gather', 1), ('contract', 1)]
# [('duke', 2), ('mobil', 2), ('april', 2), ('flow', 2), ('i', 2), ('ticket', 2), ('sitara', 2), ('appar', 1), ('inadvert', 1), ('roll', 1), ('deliveri', 1), ('refineri', 1), ('gas', 1), ('via', 1), ('centana', 1), ('1', 1), ('2', 1), ('3', 1), ('understand', 1), ('enter', 1), ('cover', 1), ('captur', 1), ('transact', 1), ('util', 1), ('follow', 1)]
# [('april', 2), ('i', 1), ('still', 1), ('concern', 1), ('nom', 1), ('take', 1), ('zero', 1), ('could', 1), ('possibl', 1), ('alloc', 1), ('group', 1), ('ad', 1), ('volum', 1), ('barrett', 1), ('deal', 1), ('this', 1), ('would', 1), ('incorrect', 1)]
# [('cn', 5), ('enron', 4), ('o', 3), ('ou', 2), ('na', 2), ('recipi', 2), ('neal', 2), ('d', 2), ('winfre', 2), ('hou', 2), ('ect', 2), ('x', 1), ('to', 1), ('farmer', 1), ('daren', 1), ('j', 1), ('dfarmer', 1), ('terri', 1), ('edward', 1), ('notesaddr', 1), ('7b023d70', 1), ('6fbeacfb', 1), ('86256498', 1), ('4f8d6c', 1), ('so', 1)]
# [('rate', 7), ('establish', 4), ('end', 3), ('the', 2), ('transport', 2), ('meter', 2), ('compani', 2), ('period', 2), ('2001', 2), ('9889', 2), ('set', 2), ('subject', 1), ('6', 1), ('1', 1), ('96', 1), ('gas', 1), ('gather', 1), ('agreement', 1), ('gulf', 1), ('coast', 1), ('pipelin', 1), ('houston', 1), ('pipe', 1), ('line', 1), ('96008709', 1), ('stagger', 1), ('time', 1), ('thus', 1), ('6677', 1), ('2', 1), ('28', 1), ('4555', 1), ('9618', 1), ('4', 1), ('30', 1), ('due', 1), ('recent', 1), ('subsequ', 1), ('date', 1), ('first', 1), ('three', 1), ('forth', 1), ('agre', 1), ('parti', 1), ('may', 1), ('pleas', 1), ('make', 1), ('sure', 1), ('proper', 1), ('attach', 1), ('sitara', 1), ('deal', 1), ('follow', 1)]
# [('i', 3), ('chang', 2), ('highlght', 1), ('spreadsheet', 1), ('look', 1), ('call', 1), ('question', 1), ('a', 1), ('coupl', 1), ('deal', 1), ('gas', 1), ('daili', 1), ('tier', 1), ('move', 1), ('sheet', 1), ('would', 1), ('like', 1), ('make', 1), ('tomorrow', 1), ('trade', 1)]
# [('purchas', 2), ('price', 2), ('fyi', 1), ('anytim', 1), ('done', 1), ('industri', 1), ('point', 1), ('fix', 1), ('kept', 1), ('whole', 1), ('onli', 1), ('buyback', 1), ('gas', 1), ('daili', 1), ('take', 1), ('swing', 1)]
# [('deal', 2), ('to', 1), ('recap', 1), ('talk', 1), ('morn', 1), ('the', 1), ('follow', 1), ('done', 1), ('june', 1), ('ena', 1), ('show', 1), ('system', 1), ('therefor', 1), ('pay', 1)]
# [('daren', 1), ('megan', 1), ('gone', 1), ('i', 1), ('want', 1), ('touch', 1), ('base', 1), ('status', 1), ('enron', 1), ('payment', 1), ('owe', 1), ('cleburn', 1), ('plant', 1), ('the', 1), ('current', 1), ('issu', 1), ('follow', 1)]
# [('at', 1), ('10', 1), ('second', 1), ('2', 1), ('min', 1), ('left', 1), ('1st', 1), ('quarter', 1), ('neb', 1), ('colo', 1), ('game', 1), ('i', 1), ('struck', 1), ('color', 1), ('discret', 1), ('better', 1), ('part', 1), ('valor', 1), ('my', 1), ('aggi', 1), ('neighbor', 1), ('saw', 1), ('take', 1), ('laugh', 1), ('imagin', 1)]
# [('know', 2), ('i', 2), ('situat', 1), ('get', 1), ('tenaska', 1), ('agreement', 1), ('sign', 1), ('list', 1), ('assign', 1), ('hpl', 1), ('sale', 1), ('think', 1), ('ever', 1), ('execut', 1), ('left', 1), ('messag', 1), ('week', 1), ('ago', 1), ('inform', 1), ('owe', 1)]
# [('i', 5), ('get', 3), ('on', 2), ('need', 2), ('report', 2), ('email', 2), ('put', 2), ('togeth', 2), ('stuff', 2), ('monday', 1), ('file', 1), ('transit', 1), ('plan', 1), ('louis', 1), ('kitchen', 1), ('netco', 1), ('she', 1), ('want', 1), ('detail', 1), ('note', 1), ('status', 1), ('desk', 1), ('effort', 1), ('start', 1), ('contract', 1), ('process', 1), ('pipe', 1), ('tpa', 1), ('ebb', 1), ('includ', 1), ('receiv', 1), ('howev', 1), ('would', 1), ('like', 1), ('manag', 1), ('summari', 1), ('excel', 1), ('spreadsheet', 1), ('suzann', 1), ('consolid', 1), ('alreadi', 1), ('pleas', 1), ('cover', 1), ('key', 1), ('item', 1), ('list', 1), ('earlier', 1), ('also', 1), ('much', 1), ('hard', 1), ('copi', 1), ('possibl', 1), ('proceed', 1), ('goal', 1), ('prepar', 1), ('startup', 1), ('suggest', 1), ('review', 1), ('paperwork', 1), ('identifi', 1), ('form', 1), ('complet', 1), ('no', 1), ('doubt', 1), ('substanti', 1), ('gap', 1), ('long', 1), ('know', 1), ('proper', 1), ('intern', 1), ('peopl', 1), ('involv', 1), ('legal', 1), ('credit', 1), ('etc', 1)]
# [('gas', 3), ('txu', 2), ('show', 2), ('hub', 2), ('daili', 2), ('midpoint', 2), ('pleas', 1), ('confirm', 1), ('price', 1), ('deal', 1), ('646679', 1), ('march', 1), ('8', 1), ('2001', 1), ('we', 1), ('current', 1), ('kati', 1), ('day', 1), ('waha', 1)]
# [('path', 2), ('deal', 2), ('januari', 2), ('februari', 2), ('2001', 2), ('i', 1), ('show', 1), ('951474', 1), ('8', 1), ('23', 1), ('01', 1), ('product', 1), ('month', 1), ('this', 1), ('expir', 1), ('12', 1), ('31', 1), ('00', 1), ('late', 1), ('caus', 1), ('bridgeback', 1), ('error', 1)]
# [('deal', 4), ('i', 3), ('teja', 2), ('the', 2), ('6', 2), ('anyth', 2), ('exxonkati', 2), ('ena', 1), ('invoic', 1), ('coral', 1), ('energi', 1), ('two', 1), ('june', 1), ('2001', 1), ('see', 1), ('system', 1), ('first', 1), ('1', 1), ('5', 1), ('400', 1), ('3', 1), ('87', 1), ('second', 1), ('13', 1), ('22', 1), ('000', 1), ('4', 1), ('25', 1), ('do', 1), ('know', 1), ('think', 1), ('would', 1), ('show', 1), ('find', 1), ('path', 1), ('manag', 1)]
# [('global', 3), ('take', 1), ('account', 1), ('may', 1), ('wrong', 1), ('someth', 1), ('either', 1), ('assign', 1), ('number', 1), ('get', 1), ('updat', 1), ('notifi', 1), ('pipe', 1)]
# [('would', 2), ('deal', 2), ('joe', 1), ('park', 1), ('told', 1), ('handl', 1), ('clebur', 1), ('estat', 1), ('team', 1), ('attach', 1), ('form', 1), ('need', 1), ('basic', 1), ('inform', 1), ('let', 1), ('know', 1), ('like', 1), ('go', 1)]
# []
# []
# [('i', 3), ('deal', 3), ('01', 2), ('it', 2), ('daren', 1), ('thu', 1), ('ask', 1), ('extend', 1), ('343421', 1), ('thru', 1), ('feb', 1), ('told', 1), ('author', 1), ('equistar', 1), ('look', 1), ('like', 1), ('term', 1), ('expir', 1), ('jan', 1), ('she', 1), ('want', 1), ('ad', 1), ('keep', 1), ('ena', 1), ('whole', 1), ('what', 1), ('suggest', 1)]
# [('meter', 2), ('1', 1), ('9643', 1), ('hgpl', 1), ('hpl', 1), ('stratton', 1), ('tejon', 1), ('oper', 1), ('corpor', 1), ('sitara', 1), ('266970', 1), ('should', 1), ('purchas', 1), ('9638', 1), ('freeman', 1), ('prod', 1), ('maxin', 1), ('field', 1), ('trade', 1), ('zone', 1), ('18', 1)]
# []
# [('inform', 2), ('we', 1), ('still', 1), ('need', 1), ('detail', 1), ('credit', 1), ('evlauat', 1), ('pleas', 1), ('send', 1), ('barri', 1), ('tycholiz', 1), ('asap', 1), ('enron', 1), ('corp', 1), ('1400', 1), ('smith', 1), ('street', 1), ('houston', 1), ('tx', 1), ('77002', 1)]
# [('hobson', 2), ('frank', 2), ('com', 2), ('enron', 2), ('w', 1), ('elpaso', 1), ('mailto', 1), ('imceanot', 1), ('22hobson', 1), ('2c', 1), ('20w', 1), ('2e', 1), ('20frank', 1), ('22', 1), ('20', 1), ('3cfrank', 1), ('2ehobson', 1), ('40elpaso', 1), ('2ecom', 1), ('3e', 1), ('40enron', 1)]
# [('x', 1), ('cc', 1), ('janet', 1), ('h', 1), ('walli', 1), ('ami', 1), ('chokshi', 1), ('howard', 1), ('b', 1), ('camp', 1), ('thu', 1), ('nguyen', 1), ('kyle', 1), ('r', 1), ('lilli', 1), ('stacey', 1), ('neuweil', 1), ('georg', 1), ('grant', 1), ('juli', 1), ('meyer', 1), ('daren', 1), ('j', 1), ('farmer', 1), ('kathryn', 1), ('cord', 1), ('rita', 1), ('wynn', 1), ('lisa', 1), ('csiko', 1), ('pamela', 1), ('chamber', 1)]
# [('adjust', 3), ('would', 2), ('make', 2), ('vs', 2), ('sch', 2), ('6', 2), ('jim', 1), ('far', 1), ('back', 1), ('like', 1), ('here', 1), ('spreadsheet', 1), ('compar', 1), ('book', 1), ('the', 1), ('net', 1), ('analysi', 1), ('withdrawn', 1), ('schedul', 1), ('in', 1), ('end', 1), ('result', 1), ('21', 1), ('259', 1)]
# [('a', 2), ('x', 1), ('cc', 1), ('lauri', 1), ('allen', 1), ('gari', 1), ('hank', 1), ('jame', 1), ('mckay', 1), ('earl', 1), ('tisdal', 1), ('brenda', 1), ('f', 1), ('herod', 1), ('edward', 1), ('d', 1), ('gottlob', 1), ('daren', 1), ('j', 1), ('farmer', 1), ('stacey', 1), ('neuweil', 1), ('rita', 1), ('wynn', 1), ('howard', 1), ('b', 1), ('camp', 1), ('steve', 1), ('venturato', 1)]
# [('i', 4), ('buy', 2), ('load', 2), ('hedg', 2), ('100', 1), ('agreement', 1), ('anyth', 1), ('cover', 1), ('nov', 1), ('right', 1), ('aga', 1), ('came', 1), ('long', 1), ('term', 1), ('market', 1), ('yet', 1), ('lift', 1), ('so', 1), ('keep', 1), ('screw', 1), ('us', 1), ('fornic', 1), ('know', 1)]
# [('i', 2), ('onpeak', 2), ('sale', 2), ('as', 1), ('discuss', 1), ('earlier', 1), ('propos', 1), ('ramp', 1), ('late', 1), ('frontera', 1), ('made', 1), ('tomorrow', 1), ('if', 1), ('must', 1), ('sell', 1), ('offpeak', 1), ('hour', 1), ('requir', 1), ('affect', 1), ('340', 1), ('mw', 1), ('schedul', 1), ('show', 1), ('would', 1), ('almost', 1), ('negat', 1), ('profit', 1)]
# [('cn', 8), ('o', 4), ('enron', 4), ('ou', 4), ('na', 4), ('recipi', 4), ('x', 1), ('to', 1), ('forney', 1), ('john', 1), ('m', 1), ('jforney', 1), ('miller', 1), ('jeffrey', 1), ('jmiller', 1), ('saibi', 1), ('eric', 1), ('esaibi', 1), ('day', 1), ('smith', 1), ('l', 1), ('sday', 1)]
# [('i', 3), ('ercot', 2), ('put', 2), ('it', 1), ('usual', 1), ('take', 1), ('week', 1), ('flow', 1), ('date', 1), ('revis', 1), ('file', 1), ('day', 1), ('check', 1), ('first', 1), ('thing', 1), ('monday', 1), ('morn', 1), ('well', 1), ('disput', 1), ('make', 1), ('sure', 1), ('review', 1), ('interv', 1), ('price', 1), ('updat', 1), ('soon', 1), ('find', 1), ('anyth', 1), ('thank', 1), ('head', 1)]
# [('cn', 6), ('o', 3), ('enron', 3), ('ou', 3), ('na', 3), ('recipi', 3), ('x', 1), ('to', 1), ('nicolay', 1), ('christi', 1), ('l', 1), ('cnicola', 1), ('yeung', 1), ('charl', 1), ('cyeung', 1), ('maurer', 1), ('luiz', 1), ('lmaurer', 1)]
# [('3', 2), ('there', 1), ('eservic', 1), ('meet', 1), ('june', 1), ('25', 1), ('2001', 1), ('eb30c1', 1), ('00', 1), ('30', 1), ('kevin', 1), ('presto', 1), ('tom', 1), ('may', 1), ('if', 1), ('question', 1), ('i', 1), ('assist', 1), ('pleas', 1), ('let', 1), ('know', 1)]
# [('talk', 3), ('contract', 3), ('i', 3), ('we', 2), ('need', 2), ('address', 2), ('issu', 2), ('includ', 2), ('also', 2), ('instantan', 1), ('suppli', 1), ('dealt', 1), ('sand', 1), ('hill', 1), ('the', 1), ('work', 1), ('austin', 1), ('realli', 1), ('order', 1), ('call', 1), ('lonestar', 1), ('well', 1), ('janet', 1), ('walli', 1), ('help', 1), ('may', 1), ('want', 1), ('schedul', 1), ('meet', 1)]
# [('frontera', 5), ('process', 2), ('input', 2), ('buy', 2), ('epmi', 2), ('side', 2), ('chang', 1), ('increas', 1), ('generat', 1), ('the', 1), ('current', 1), ('sell', 1), ('this', 1), ('intuit', 1), ('caus', 1), ('confus', 1), ('whi', 1), ('would', 1), ('trade', 1), ('it', 1), ('could', 1), ('simpl', 1), ('click', 1), ('box', 1), ('indic', 1), ('adjust', 1), ('resourc', 1), ('oblig', 1)]
# [('would', 2), ('like', 2), ('current', 2), ('send', 2), ('as', 1), ('discuss', 1), ('notifi', 1), ('custom', 1), ('status', 1), ('abil', 1), ('look', 1), ('here', 1), ('brief', 1), ('summari', 1), ('servic', 1), ('contract', 1), ('oblig', 1), ('along', 1), ('notif', 1), ('letter', 1), ('pleas', 1), ('let', 1), ('us', 1), ('know', 1), ('ok', 1)]
# [('tom', 2), ('to', 1), ('imai', 1), ('rika', 1), ('soykok', 1), ('gulay', 1), ('gilbert', 1), ('smith', 1), ('doug', 1), ('hans', 1), ('patrick', 1), ('rust', 1), ('bill', 1), ('coffer', 1), ('walter', 1), ('kraszewski', 1), ('robert', 1), ('lin', 1), ('martin', 1), ('koh', 1), ('sandeep', 1), ('halliburton', 1), ('will', 1), ('lloyd', 1), ('may', 1), ('yaman', 1), ('sevil', 1), ('huang', 1), ('alex', 1), ('shanbhogu', 1), ('vasant', 1)]
# [('i', 2), ('need', 1), ('answer', 1), ('6', 1), ('15', 1), ('01', 1), ('tenaska', 1), ('lds', 1), ('gave', 1), ('week', 1), ('ago', 1), ('they', 1), ('call', 1), ('daili', 1), ('ask', 1), ('status', 1), ('sent', 1), ('invoic', 1), ('payment', 1), ('today', 1)]
# [('aep', 2), ('respond', 1), ('late', 1), ('thursday', 1), ('11', 1), ('8', 1), ('01', 1), ('small', 1), ('chang', 1), ('elizabeth', 1), ('sager', 1), ('redraft', 1), ('master', 1), ('setoff', 1), ('agr', 1), ('certain', 1), ('european', 1), ('affili', 1), ('enron', 1), ('canada', 1), ('corp', 1), ('brought', 1), ('our', 1), ('credit', 1), ('group', 1), ('indic', 1), ('friday', 1), ('would', 1), ('inform', 1), ('legal', 1), ('final', 1), ('matter', 1), ('resolv', 1)]
# [('var', 3), ('pleas', 1), ('verifi', 1), ('john', 1), ('chang', 1), ('make', 1), ('sens', 1), ('perspect', 1), ('given', 1), ('independ', 1), ('analysi', 1), ('price', 1), ('curv', 1), ('the', 1), ('exist', 1), ('calcul', 1), ('assum', 1), ('power', 1), ('gas', 1), ('correl', 1), ('texa', 1), ('47', 1), ('empir', 1), ('evid', 1), ('show', 1), ('someth', 1), ('order', 1), ('93', 1), ('i', 1), ('believ', 1), ('provid', 1), ('data', 1), ('mike', 1), ('found', 1), ('accur', 1), ('agre', 1), ('drop', 1), ('amount', 1), ('state', 1)]
# [('ub', 3), ('ercot', 2), ('legal', 1), ('credit', 1), ('head', 1), ('houston', 1), ('thursday', 1), ('friday', 1), ('i', 1), ('ask', 1), ('matter', 1), ('get', 1), ('1', 1), ('hour', 1), ('discuss', 1), ('necessari', 1), ('contract', 1), ('need', 1), ('sign', 1), ('particip', 1), ('market', 1)]
# [('take', 3), ('minut', 2), ('4', 1), ('the', 1), ('whole', 1), ('process', 1), ('long', 1), ('averag', 1), ('usual', 1), ('5', 1), ('put', 1), ('hour', 1), ('schedul', 1), ('done', 1), ('direct', 1), ('portal', 1)]
# []
# [('cn', 16), ('o', 9), ('enron', 8), ('ou', 8), ('na', 8), ('recipi', 8), ('x', 1), ('cc', 1), ('neil', 1), ('murray', 1), ('p', 1), ('moneil', 1), ('purcel', 1), ('mike', 1), ('mpurcel', 1), ('robinson', 1), ('donald', 1), ('drobin', 1), ('cutsforth', 1), ('dian', 1), ('dcutsfor', 1), ('bishop', 1), ('serena', 1), ('sbishop3', 1), ('crandal', 1), ('sean', 1), ('scranda', 1), ('scholt', 1), ('diana', 1), ('dscholt', 1), ('belden', 1), ('tim', 1), ('tbelden', 1)]
# [('x', 1), ('to', 1), ('michael', 1), ('olsen', 1), ('tom', 1), ('acton', 1), ('clem', 1), ('cernosek', 1), ('robert', 1), ('cotten', 1), ('jacki', 1), ('young', 1), ('sabra', 1), ('zajac', 1), ('carlo', 1), ('j', 1), ('rodriguez', 1), ('mark', 1), ('mccoy', 1), ('aime', 1), ('lannou', 1), ('mari', 1), ('poorman', 1), ('eddi', 1), ('janzen', 1)]
# []
# [('it', 2), ('trade', 2), ('deal', 2), ('question', 2), ('i', 2), ('look', 1), ('like', 1), ('crosstimb', 1), ('phys', 1), ('us', 1), ('nwpl', 1), ('rox', 1), ('025', 1), ('also', 1), ('fin', 1), ('nymex', 1), ('basi', 1), ('we', 1), ('combin', 1), ('essenti', 1), ('make', 1), ('jan01', 1), ('fix', 1), ('price', 1), ('appear', 1), ('custom', 1), ('whi', 1), ('8', 1), ('month', 1), ('settlement', 1), ('date', 1), ('idea', 1), ('alreadi', 1), ('spoke', 1), ('carol', 1), ('ticket', 1), ('ask', 1)]
# [('i', 2), ('here', 1), ('bob', 1), ('cotten', 1), ('say', 1), ('big', 1), ('cowboy', 1), ('think', 1), ('tri', 1), ('conoco', 1), ('send', 1), ('money', 1), ('back', 1), ('determin', 1), ('bought', 1), ('gas', 1)]
# [('gepl', 3), ('tom', 3), ('purchas', 2), ('conoco', 2), ('edit', 2), ('deal', 2), ('ticket', 2), ('includ', 2), ('meter', 2), ('27', 2), ('08', 2), ('i', 2), ('the', 1), ('april', 1), ('may', 1), ('nomin', 1), ('spreadsheet', 1), ('produc', 1), ('servic', 1), ('reflect', 1), ('hpl', 1), ('there', 1), ('refer', 1), ('on', 1), ('june', 1), ('6', 1), ('2001', 1), ('acton', 1), ('133304', 1), ('002', 1), ('003', 1), ('idea', 1), ('longer', 1), ('aep', 1), ('find', 1), ('document', 1), ('support', 1), ('chang', 1), ('pleas', 1), ('advis', 1), ('need', 1), ('addit', 1), ('inform', 1)]
# [('approv', 2), ('vinc', 1), ('kaminiski', 1), ('request', 1), ('acc', 1), ('technic', 1), ('view', 1), ('catalog', 1), ('along', 1), ('ibuyit', 1), ('role', 1), ('this', 1), ('pend', 1), ('pleas', 1), ('send', 1), ('respons', 1), ('sap', 1), ('secur', 1)]
# [('e', 5), ('mail', 5), ('mari', 2), ('david', 2), ('peter', 2), ('to', 1), ('aronowitz', 1), ('alan', 1), ('athena', 1), ('alexand', 1), ('clark', 1), ('morri', 1), ('cook', 1), ('mitchel', 1), ('davi', 1), ('angela', 1), ('del', 1), ('vecchio', 1), ('dougla', 1), ('stephen', 1), ('h', 1), ('evan', 1), ('mark', 1), ('london', 1), ('legal', 1), ('gaffney', 1), ('chris', 1), ('gray', 1), ('barbara', 1), ('n', 1), ('hansen', 1), ('lesli', 1), ('heard', 1), ('hendri', 1), ('brent', 1), ('hodg', 1), ('jeffrey', 1), ('t', 1), ('johnston', 1), ('greg', 1), ('jone', 1), ('tana', 1), ('keohan', 1), ('koehler', 1), ('ann', 1), ('c', 1), ('lech', 1), ('kalembka', 1), ('leit', 1), ('francisco', 1), ('pinto', 1), ('marissa', 1), ('morell', 1), ('mccullough', 1), ('travi', 1), ('mellencamp', 1), ('lisa', 1), ('murphi', 1), ('harlan', 1), ('murray', 1), ('julia', 1), ('nemec', 1), ('gerald', 1), ('portz', 1), ('rick', 1), ('antonoff', 1), ('rohauer', 1), ('tanya', 1), ('sager', 1), ('elizabeth', 1), ('saxena', 1), ('rahul', 1), ('sayr', 1), ('frank', 1), ('schuh', 1), ('michael', 1), ('shackleton', 1), ('sara', 1), ('simon', 1), ('paul', 1), ('st', 1), ('clair', 1), ('carol', 1), ('van', 1), ('hooser', 1), ('steve', 1), ('viverito', 1), ('john', 1), ('von', 1), ('bock', 1), ('und', 1), ('polach', 1), ('marcus', 1), ('william', 1), ('jason', 1), ('r', 1), ('credit', 1)]
# [('termin', 2), ('notic', 2), ('elizabeth', 1), ('sager', 1), ('indic', 1), ('wabash', 1), ('given', 1), ('appropri', 1), ('transact', 1), ('associ', 1), ('eei', 1), ('i', 1), ('confirm', 1), ('david', 1), ('portz', 1), ('make', 1), ('sure', 1), ('cover', 1), ('one', 1), ('contract', 1), ('event', 1), ('exist', 1)]
# [('1', 3), ('corp', 2), ('enron', 2), ('com', 2), ('8', 2), ('10', 2), ('08', 2), ('receiv', 1), ('192', 1), ('168', 1), ('110', 1), ('108', 1), ('postmast', 1), ('extern', 1), ('esmtp', 1), ('id', 1), ('f8cdqx703063', 1), ('wed', 1), ('12', 1), ('sep', 1), ('2001', 1), ('26', 1), ('33', 1), ('0500', 1), ('cdt', 1)]
# [('enron', 5), ('intend', 4), ('recipi', 4), ('corp', 3), ('this', 2), ('mail', 2), ('affili', 2), ('may', 2), ('use', 2), ('messag', 2), ('contract', 2), ('properti', 1), ('relev', 1), ('contain', 1), ('confidenti', 1), ('privileg', 1), ('materi', 1), ('sole', 1), ('ani', 1), ('review', 1), ('distribut', 1), ('disclosur', 1), ('other', 1), ('strict', 1), ('prohibit', 1), ('if', 1), ('author', 1), ('receiv', 1), ('pleas', 1), ('contact', 1), ('sender', 1), ('repli', 1), ('administr', 1), ('com', 1), ('delet', 1), ('copi', 1), ('attach', 1), ('hereto', 1), ('offer', 1), ('accept', 1), ('creat', 1), ('evid', 1), ('bind', 1), ('enforc', 1), ('parti', 1), ('reli', 1), ('anyon', 1), ('basi', 1), ('estoppel', 1), ('otherwis', 1), ('thank', 1)]
# [('portfolio', 7), ('step', 6), ('base', 5), ('1', 4), ('may', 3), ('2', 3), ('specif', 3), ('instruct', 3), ('oper', 2), ('congest', 2), ('resourc', 2), ('award', 2), ('result', 2), ('final', 2), ('dispatch', 2), ('qse', 2), ('receiv', 2), ('deploy', 2), ('therefor', 1), ('exist', 1), ('solut', 1), ('found', 1), ('augment', 1), ('modifi', 1), ('the', 1), ('alway', 1), ('set', 1), ('issu', 1), ('qses', 1), ('solv', 1), ('becaus', 1), ('equal', 1), ('net', 1), ('preliminari', 1), ('balanc', 1), ('energi', 1), ('adjust', 1), ('bid', 1), ('curv', 1), ('match', 1), ('mcpe', 1), ('determin', 1), ('this', 1), ('caus', 1), ('appear', 1), ('incorrect', 1), ('struck', 1), ('whenev', 1), ('unit', 1), ('also', 1), ('categori', 1), ('ercot', 1), ('expect', 1), ('follow', 1)]
# [('5000', 3), ('a', 2), ('b', 2), ('2500', 2), ('hour', 2), ('sinc', 1), ('money', 1), ('paid', 1), ('c', 1), ('d', 1), ('insuffici', 1), ('fulli', 1), ('reimburs', 1), ('happen', 1), ('settlement', 1), ('do', 1), ('get', 1), ('proport', 1), ('less', 1), ('otherwis', 1), ('would', 1), ('gotten', 1), ('or', 1), ('bank', 1), ('mechan', 1), ('build', 1), ('overag', 1), ('drawn', 1), ('shortag', 1), ('exampl', 1)]
# [('the', 2), ('5', 1), ('packag', 1), ('ice', 1), ('account', 1), ('accept', 1), ('txu', 1), ('load', 1), ('avail', 1), ('confirm', 1), ('814', 1), ('enrol', 1), ('request', 1), ('submit', 1), ('today', 1), ('tomorrow', 1), ('csc', 1)]
# [('pleas', 1), ('send', 1), ('item', 1), ('1', 1), ('asap', 1), ('confirm', 1), ('room', 1), ('account', 1), ('onc', 1), ('done', 1), ('put', 1), ('full', 1), ('court', 1), ('press', 1), ('august', 1)]
# [('2', 3), ('previous', 2), ('convers', 2), ('thane', 2), ('indic', 2), ('month', 2), ('pay', 2), ('60', 2), ('day', 2), ('this', 1), ('differ', 1), ('in', 1), ('could', 1), ('contract', 1), ('exampl', 1), ('lds', 1), ('point', 1), ('will', 1), ('20k', 1), ('10k', 1), ('minimum', 1), ('cancel', 1), ('prior', 1), ('notic', 1)]
# [('border', 3), ('2001', 3), ('deliveri', 2), ('point', 2), ('ercot', 2), ('buy', 2), ('sale', 2), ('1', 1), ('what', 1), ('need', 1), ('show', 1), ('trade', 1), ('system', 1), ('various', 1), ('zone', 1), ('west', 1), ('south', 1), ('north', 1), ('split', 1), ('piec', 1), ('cpbs', 1), ('form', 1), ('san', 1), ('antonio', 1), ('hlp', 1), ('rhlp', 1)]
# []
# [('giancola', 3), ('tosch', 2), ('to', 1), ('andi', 1), ('matt', 1), ('gillian', 1), ('wilson', 1), ('home', 1), ('alan', 1), ('wing', 1), ('william', 1), ('young', 1), ('dan', 1), ('michael', 1), ('mike', 1), ('david', 1), ('haddock', 1), ('pat', 1), ('martel', 1), ('miller', 1), ('jeffrey', 1)]
# [('i', 4), ('time', 2), ('thank', 1), ('communic', 1), ('add', 1), ('steve', 1), ('best', 1), ('get', 1), ('activ', 1), ('next', 1), ('pain', 1), ('thought', 1), ('realiz', 1), ('import', 1), ('gave', 1), ('note', 1), ('final', 1), ('trip', 1), ('they', 1), ('lot', 1), ('work', 1), ('info', 1), ('least', 1), ('month', 1), ('make', 1), ('room', 1), ('chang', 1), ('error', 1)]
# [('jerri', 1), ('brown', 1), ('would', 1), ('like', 1), ('know', 1), ('status', 1), ('call', 1), ('option', 1), ('light', 1), ('recent', 1), ('acquisit', 1), ('ub', 1), ('are', 1), ('individu', 1), ('provid', 1), ('clarif', 1), ('us', 1)]
# []
# [('situat', 2), ('this', 1), ('exampl', 1), ('mapp', 1), ('finest', 1), ('custom', 1), ('servic', 1), ('dustin', 1), ('suggest', 1), ('ad', 1), ('complaint', 1), ('file', 1), ('we', 1), ('want', 1), ('make', 1), ('awar', 1)]
# [('alex', 1), ('care', 1), ('enter', 1), ('hour', 1), ('deal', 1), ('enpow', 1), ('there', 1), ('one', 1), ('10th', 1), ('put', 1), ('north', 1), ('south', 1), ('brazil', 1), ('instead', 1), ('texa', 1), ('i', 1), ('chang', 1)]
# [('list', 2), ('email', 2), ('i', 1), ('know', 1), ('swamp', 1), ('excis', 1), ('prerequisit', 1), ('execut', 1), ('master', 1), ('net', 1), ('agreement', 1), ('even', 1), ('rough', 1), ('entiti', 1), ('hous', 1), ('pleas', 1), ('provid', 1), ('best', 1), ('avail', 1), ('inform', 1), ('via', 1), ('copi', 1), ('ccs', 1), ('thank', 1), ('assist', 1)]
# []
# [('e', 16), ('mail', 16), ('tom', 2), ('to', 1), ('bernard', 1), ('teal', 1), ('david', 1), ('giancola', 1), ('home', 1), ('dwayn', 1), ('young', 1), ('heath', 1), ('trousdal', 1), ('miller', 1), ('jeffrey', 1), ('kevin', 1), ('dixon', 1), ('martin', 1), ('thoma', 1), ('matt', 1), ('donnel', 1), ('melissa', 1), ('heier', 1), ('rhett', 1), ('horton', 1), ('rob', 1), ('porchey', 1), ('robert', 1), ('renner', 1), ('stephan', 1), ('eckhardt', 1), ('steve', 1), ('snyder', 1), ('franzon', 1), ('ivest', 1), ('walter', 1), ('chanc', 1)]
# [('01', 2), ('ena', 2), ('price', 2), ('dow', 1), ('hydrocarbon', 1), ('resourc', 1), ('inc', 1), ('state', 1), ('4', 1), ('24', 1), ('deal', 1), ('sa', 1), ('639615', 1), ('03', 1), ('sale', 1), ('csgt', 1), ('b368', 1), ('brazo', 1), ('368', 1), ('cowtrap', 1), ('if', 1), ('06', 1), ('we', 1), ('invoic', 1), ('hsc', 1), ('gdp', 1), ('da', 1), ('need', 1), ('know', 1), ('correct', 1), ('copi', 1), ('confirm', 1)]
# [('j', 2), ('x', 1), ('to', 1), ('thane', 1), ('twigg', 1), ('jame', 1), ('d', 1), ('steff', 1), ('jeff', 1), ('dasovich', 1), ('karen', 1), ('denn', 1), ('enron', 1), ('mona', 1), ('l', 1), ('petrochko', 1), ('paul', 1), ('kaufman', 1), ('richard', 1), ('shapiro', 1), ('sandra', 1), ('mccubbin', 1), ('steven', 1), ('kean', 1), ('susan', 1), ('mara', 1)]
# [('today', 2), ('i', 2), ('var', 2), ('million', 2), ('doug', 1), ('actual', 1), ('offic', 1), ('want', 1), ('check', 1), ('see', 1), ('issu', 1), ('revis', 1), ('correl', 1), ('engin', 1), ('the', 1), ('ercot', 1), ('desk', 1), ('6', 1), ('limit', 1), ('5', 1), ('know', 1), ('anxious', 1), ('resolv', 1)]
# [('price', 4), ('use', 3), ('function', 2), ('calc', 2), ('correl', 2), ('chang', 2), ('is', 1), ('enpow', 1), ('port', 1), ('as', 1), ('asid', 1), ('mike', 1), ('brought', 1), ('point', 1), ('excel', 1), ('actual', 1), ('similar', 1), ('ing', 1), ('pnl', 1), ('instead', 1), ('seem', 1), ('like', 1), ('oper', 1), ('second', 1), ('layer', 1), ('data', 1), ('ie', 1), ('log', 1), ('return', 1), ('varianc', 1), ('covari', 1)]
# [('food', 2), ('stuck', 2), ('thank', 1), ('dad', 1), ('problem', 1), ('digest', 1), ('late', 1), ('it', 1), ('get', 1), ('so', 1), ('sasha', 1), ('took', 1), ('hospit', 1), ('they', 1), ('use', 1), ('tube', 1), ('remov', 1), ('sure', 1), ('type', 1), ('treatment', 1), ('i', 1), ('keep', 1), ('guy', 1), ('post', 1)]
# [('cn', 12), ('o', 6), ('enron', 6), ('ou', 6), ('na', 6), ('recipi', 6), ('joe', 2), ('x', 1), ('to', 1), ('capasso', 1), ('jcapasso', 1), ('errigo', 1), ('jerrigo', 1), ('mcelreath', 1), ('alexand', 1), ('amcelrea', 1), ('miller', 1), ('jeffrey', 1), ('jmiller', 1), ('olind', 1), ('jr', 1), ('steve', 1), ('solind', 1), ('saibi', 1), ('eric', 1), ('esaibi', 1)]
# [('i', 1), ('sure', 1), ('corri', 1), ('came', 1), ('told', 1), ('happen', 1), ('monday', 1), ('it', 1), ('problem', 1), ('lisa', 1), ('come', 1), ('help', 1), ('whoever', 1), ('go', 1), ('schedul', 1)]
# [('chose', 6), ('we', 4), ('counterparti', 3), ('transact', 3), ('direct', 3), ('would', 3), ('contract', 2), ('may', 2), ('schedul', 2), ('alway', 2), ('deal', 2), ('price', 2), ('build', 1), ('time', 1), ('third', 1), ('still', 1), ('administ', 1), ('perform', 1), ('etc', 1), ('in', 1), ('way', 1), ('custom', 1), ('i', 1), ('believ', 1), ('serv', 1), ('counteract', 1), ('concern', 1), ('provid', 1), ('fair', 1), ('market', 1), ('sinc', 1), ('could', 1), ('confid', 1), ('competit', 1), ('us', 1), ('cours', 1), ('need', 1), ('protect', 1), ('share', 1), ('benefit', 1), ('case', 1), ('someon', 1), ('els', 1)]
# [('pleas', 1), ('comment', 1), ('correct', 1), ('add', 1), ('subtract', 1), ('david', 1), ('fairley', 1), ('i', 1), ('send', 1), ('market', 1), ('strategi', 1), ('trade', 1), ('risk', 1), ('polici', 1), ('later', 1), ('morn', 1)]
# [('meter', 5), ('nomin', 3), ('month', 2), ('gepl', 2), ('hgpl', 2), ('flow', 2), ('system', 2), ('000', 2), ('i', 2), ('we', 1), ('ongo', 1), ('issu', 1), ('everi', 1), ('king', 1), ('ranch', 1), ('8284', 1), ('purchas', 1), ('gas', 1), ('upstream', 1), ('the', 1), ('volum', 1), ('anywher', 1), ('6', 1), ('10', 1), ('day', 1), ('least', 1), ('past', 1), ('six', 1), ('would', 1), ('pleas', 1), ('fax', 1), ('statement', 1), ('februari', 1), ('tri', 1), ('determin', 1), ('verifi', 1), ('deal', 1), ('offsystem', 1), ('should', 1), ('requir', 1), ('specif', 1), ('list', 1), ('tom', 1), ('schemat', 1), ('area', 1)]
# [('x', 1), ('to', 1), ('michael', 1), ('olsen', 1), ('edward', 1), ('terri', 1), ('tom', 1), ('acton', 1), ('clem', 1), ('cernosek', 1), ('robert', 1), ('cotten', 1), ('jacki', 1), ('young', 1), ('sabra', 1), ('zajac', 1), ('carlo', 1), ('j', 1), ('rodriguez', 1), ('mark', 1), ('mccoy', 1), ('aime', 1), ('lannou', 1), ('mari', 1), ('poorman', 1), ('eddi', 1), ('janzen', 1)]
# []
# [('hou', 7), ('ect', 7), ('enron', 7), ('robert', 3), ('lisa', 2), ('smith', 2), ('mari', 2), ('gari', 2), ('j', 2), ('to', 1), ('carrier', 1), ('molli', 1), ('cernosek', 1), ('clem', 1), ('consemiu', 1), ('donna', 1), ('cook', 1), ('camp', 1), ('howard', 1), ('hess', 1), ('hlavati', 1), ('nathan', 1), ('wayn', 1), ('e', 1), ('lightfoot', 1), ('mckay', 1), ('jame', 1), ('schneider', 1), ('steve', 1), ('hpl', 1), ('melissa', 1), ('grave', 1), ('walter', 1), ('michael', 1), ('zivley', 1), ('jill', 1), ('johnson', 1), ('jo', 1), ('wynn', 1), ('rita', 1), ('allen', 1), ('lauri', 1), ('jone', 1), ('cheryl', 1), ('hansen', 1), ('reid', 1), ('giron', 1), ('darron', 1), ('winfre', 1), ('o', 1), ('neal', 1), ('susan', 1), ('bryan', 1), ('hank', 1), ('donald', 1), ('p', 1), ('reinhardt', 1), ('vanc', 1), ('l', 1), ('taylor', 1), ('baumbach', 1), ('david', 1), ('cotten', 1), ('riley', 1), ('brian', 1), ('austin', 1), ('jeff', 1), ('hakemack', 1), ('cynthia', 1), ('kenn', 1), ('dawn', 1), ('csiko', 1), ('fosdick', 1), ('r', 1), ('rodriguez', 1), ('carlo', 1), ('gome', 1), ('stephani', 1), ('clyne', 1), ('pat', 1), ('acton', 1), ('tom', 1), ('walker', 1), ('weissman', 1), ('georg', 1), ('harri', 1), ('joann', 1), ('sweeney', 1), ('christi', 1), ('tisdal', 1), ('earl', 1), ('daren', 1), ('farmer', 1)]
# [('enron', 6), ('cn', 6), ('hou', 4), ('ect', 4), ('j', 2), ('farmer', 2), ('o', 2), ('ou', 2), ('na', 2), ('recipi', 2), ('notesaddr', 2), ('grave', 2), ('x', 1), ('cc', 1), ('daren', 1), ('sdaren', 1), ('riley', 1), ('brian', 1), ('70b51a14', 1), ('6bd54b96', 1), ('86256515', 1), ('4b9bef', 1), ('melissa', 1), ('smelissa', 1), ('gottlob', 1), ('edward', 1), ('d576b619', 1), ('e9d1d35b', 1), ('86256514', 1), ('723d81', 1)]
# [('to', 1), ('lamadrid', 1), ('victor', 1), ('kinsey', 1), ('lisa', 1), ('sullivan', 1), ('patti', 1), ('jaquet', 1), ('tammi', 1), ('greif', 1), ('donna', 1), ('smith', 1), ('georg', 1), ('f', 1), ('oling', 1), ('kimber', 1), ('s', 1), ('farmer', 1), ('daren', 1), ('j', 1), ('calcagno', 1), ('suzann', 1), ('william', 1), ('jason', 1), ('trade', 1)]
# [('deal', 3), ('640685', 1), ('march', 1), ('01', 1), ('product', 1), ('per', 1), ('daren', 1), ('farmer', 1), ('audit', 1), ('field', 1), ('sitara', 1), ('copi', 1), ('547201', 1), ('this', 1), ('crude', 1), ('swap', 1), ('volum', 1), ('stay', 1), ('price', 1), ('got', 1), ('zero', 1), ('book', 1), ('demand', 1), ('charg', 1), ('679847', 1), ('679848', 1)]
# [('enter', 2), ('ticket', 2), ('01', 2), ('hpl', 1), ('sale', 1), ('ena', 1), ('valu', 1), ('gas', 1), ('zero', 1), ('this', 1), ('demand', 1), ('charg', 1), ('amount', 1), ('974', 1), ('144', 1), ('1', 1), ('766', 1), ('304', 1), ('2', 1)]
# [('i', 2), ('if', 1), ('provid', 1), ('enough', 1), ('inform', 1), ('question', 1), ('pleas', 1), ('hesit', 1), ('give', 1), ('call', 1), ('as', 1), ('need', 1), ('resolv', 1), ('issu', 1), ('soon', 1), ('possibl', 1), ('prompt', 1), ('attent', 1), ('matter', 1), ('would', 1), ('appreci', 1)]
# [('spinnak', 2), ('gas', 2), ('purchas', 2), ('price', 2), ('do', 1), ('pay', 1), ('see', 1), ('daren', 1), ('question', 1), ('03', 1), ('01', 1), ('144271', 1), ('144264', 1), ('need', 1), ('know', 1), ('if', 1), ('daili', 1)]
# [('com', 3), ('mltrochta', 2), ('dow', 2), ('mailto', 2), ('enron', 2), ('20', 2), ('trochta', 1), ('mari', 1), ('ml', 1), ('imceanot', 1), ('22trochta', 1), ('2c', 1), ('20mari', 1), ('28ml', 1), ('29', 1), ('22', 1), ('3cmltrochta', 1), ('40dow', 1), ('2ecom', 1), ('3e', 1), ('40enron', 1)]
# [('gas', 2), ('flow', 2), ('if', 2), ('term', 2), ('can', 1), ('verifi', 1), ('bill', 1), ('deal', 1), ('one', 1), ('place', 1), ('invoic', 1), ('let', 1), ('know', 1), ('i', 1), ('put', 1)]
# [('x', 1), ('to', 1), ('howard', 1), ('b', 1), ('camp', 1), ('sherlyn', 1), ('schumack', 1), ('gregori', 1), ('steagal', 1), ('anita', 1), ('luong', 1), ('charlott', 1), ('hawkin', 1), ('robert', 1), ('e', 1), ('lloyd', 1), ('heidi', 1), ('wither', 1), ('stacey', 1), ('neuweil', 1), ('daren', 1), ('j', 1), ('farmer', 1)]
# [('need', 3), ('the', 1), ('pop', 1), ('meter', 1), ('7107', 1), ('7108', 1), ('7109', 1), ('stay', 1), ('non', 1), ('allocat', 1), ('alloc', 1), ('unit', 1), ('gas', 1), ('pipelin', 1), ('you', 1), ('daren', 1), ('michael', 1), ('enron', 1), ('follow', 1)]
# [('j', 2), ('x', 1), ('to', 1), ('lee', 1), ('l', 1), ('papayoti', 1), ('daren', 1), ('farmer', 1), ('gari', 1), ('w', 1), ('lamphier', 1), ('david', 1), ('baumbach', 1), ('lisa', 1), ('csiko', 1), ('joani', 1), ('h', 1), ('ngo', 1), ('jennif', 1), ('blay', 1), ('rita', 1), ('wynn', 1), ('kristen', 1), ('hanson', 1), ('aime', 1), ('lannou', 1)]
# [('deliv', 2), ('8', 1), ('30am', 1), ('notifi', 1), ('gas', 1), ('control', 1), ('freeport', 1), ('deliveri', 1), ('dow', 1), ('increas', 1), ('10', 1), ('0', 1), ('also', 1), ('exxon', 1), ('kati', 1), ('approx', 1), ('7', 1), ('9', 1), ('mmbtu', 1), ('similar', 1), ('volum', 1), ('friday', 1), ('confrim', 1), ('jacki', 1), ('ok', 1), ('saturday', 1)]
# [('cn', 32), ('o', 16), ('enron', 16), ('ou', 16), ('na', 16), ('recipi', 16), ('e', 3), ('mail', 2), ('x', 1), ('to', 1), ('bharati', 1), ('rakesh', 1), ('rbharati', 1), ('brackett', 1), ('debbi', 1), ('r', 1), ('dbrack', 1), ('chang', 1), ('hang', 1), ('hchang3', 1), ('de', 1), ('rabi', 1), ('rde', 1), ('gorni', 1), ('vladimir', 1), ('vgorni', 1), ('hayden', 1), ('frank', 1), ('fhayden', 1), ('jia', 1), ('winston', 1), ('wjia', 1), ('lew', 1), ('jaesoo', 1), ('jlew', 1), ('nordstrom', 1), ('mari', 1), ('mnordst2', 1), ('presley', 1), ('mike', 1), ('mpresley', 1), ('ruan', 1), ('mark', 1), ('mruan', 1), ('sokolov', 1), ('jason', 1), ('jsokolo', 1), ('sriram', 1), ('vasudevan', 1), ('svasudev', 1), ('tamarchenko', 1), ('tanya', 1), ('ttamarc', 1), ('vinc', 1), ('j', 1), ('kaminski', 1), ('vkamin', 1), ('wei', 1), ('dave', 1), ('dwei', 1)]

# %%
top_words_list = dict.fromkeys(authors_list,[])
for author in authors_list:
    if (word_frequencies[author]):
        list_tuples = word_frequencies[author][:10]
        top_words_list[author] = (list(list(zip(*list_tuples))[0]))
        
print(top_words_list)
# Out:
# {1: ['x', 'to', 'robert', 'cotten', 'jacki', 'young', 'charlott', 'hawkin', 'carlo', 'j'], 2: ['deal', 'fyi', 'creat', 'submit', 'commit', 'reserv', 'firm', 'ticket', 'remain', 'term'], 3: ['duke', 'mobil', 'april', 'flow', 'i', 'ticket', 'sitara', 'appar', 'inadvert', 'roll'], 4: ['april', 'i', 'still', 'concern', 'nom', 'take', 'zero', 'could', 'possibl', 'alloc'], 5: ['cn', 'enron', 'o', 'ou', 'na', 'recipi', 'neal', 'd', 'winfre', 'hou'], 6: ['rate', 'establish', 'end', 'the', 'transport', 'meter', 'compani', 'period', '2001', '9889'], 7: ['i', 'chang', 'highlght', 'spreadsheet', 'look', 'call', 'question', 'a', 'coupl', 'deal'], 8: ['purchas', 'price', 'fyi', 'anytim', 'done', 'industri', 'point', 'fix', 'kept', 'whole'], 9: ['deal', 'to', 'recap', 'talk', 'morn', 'the', 'follow', 'done', 'june', 'ena'], 10: ['daren', 'megan', 'gone', 'i', 'want', 'touch', 'base', 'status', 'enron', 'payment'], 11: ['at', '10', 'second', '2', 'min', 'left', '1st', 'quarter', 'neb', 'colo'], 12: ['know', 'i', 'situat', 'get', 'tenaska', 'agreement', 'sign', 'list', 'assign', 'hpl'], 13: ['i', 'get', 'on', 'need', 'report', 'email', 'put', 'togeth', 'stuff', 'monday'], 14: ['gas', 'txu', 'show', 'hub', 'daili', 'midpoint', 'pleas', 'confirm', 'price', 'deal'], 15: ['path', 'deal', 'januari', 'februari', '2001', 'i', 'show', '951474', '8', '23'], 16: ['deal', 'i', 'teja', 'the', '6', 'anyth', 'exxonkati', 'ena', 'invoic', 'coral'], 17: ['global', 'take', 'account', 'may', 'wrong', 'someth', 'either', 'assign', 'number', 'get'], 18: ['would', 'deal', 'joe', 'park', 'told', 'handl', 'clebur', 'estat', 'team', 'attach'], 19: [], 20: [], 21: ['i', 'deal', '01', 'it', 'daren', 'thu', 'ask', 'extend', '343421', 'thru'], 22: ['meter', '1', '9643', 'hgpl', 'hpl', 'stratton', 'tejon', 'oper', 'corpor', 'sitara'], 23: [], 24: ['inform', 'we', 'still', 'need', 'detail', 'credit', 'evlauat', 'pleas', 'send', 'barri'], 25: ['hobson', 'frank', 'com', 'enron', 'w', 'elpaso', 'mailto', 'imceanot', '22hobson', '2c'], 26: ['x', 'cc', 'janet', 'h', 'walli', 'ami', 'chokshi', 'howard', 'b', 'camp'], 27: ['adjust', 'would', 'make', 'vs', 'sch', '6', 'jim', 'far', 'back', 'like'], 28: ['a', 'x', 'cc', 'lauri', 'allen', 'gari', 'hank', 'jame', 'mckay', 'earl'], 29: ['i', 'buy', 'load', 'hedg', '100', 'agreement', 'anyth', 'cover', 'nov', 'right'], 30: ['i', 'onpeak', 'sale', 'as', 'discuss', 'earlier', 'propos', 'ramp', 'late', 'frontera'], 31: ['cn', 'o', 'enron', 'ou', 'na', 'recipi', 'x', 'to', 'forney', 'john'], 32: ['i', 'ercot', 'put', 'it', 'usual', 'take', 'week', 'flow', 'date', 'revis'], 33: ['cn', 'o', 'enron', 'ou', 'na', 'recipi', 'x', 'to', 'nicolay', 'christi'], 34: ['3', 'there', 'eservic', 'meet', 'june', '25', '2001', 'eb30c1', '00', '30'], 35: ['talk', 'contract', 'i', 'we', 'need', 'address', 'issu', 'includ', 'also', 'instantan'], 36: ['frontera', 'process', 'input', 'buy', 'epmi', 'side', 'chang', 'increas', 'generat', 'the'], 37: ['would', 'like', 'current', 'send', 'as', 'discuss', 'notifi', 'custom', 'status', 'abil'], 38: ['tom', 'to', 'imai', 'rika', 'soykok', 'gulay', 'gilbert', 'smith', 'doug', 'hans'], 39: ['i', 'need', 'answer', '6', '15', '01', 'tenaska', 'lds', 'gave', 'week'], 40: ['aep', 'respond', 'late', 'thursday', '11', '8', '01', 'small', 'chang', 'elizabeth'], 41: ['var', 'pleas', 'verifi', 'john', 'chang', 'make', 'sens', 'perspect', 'given', 'independ'], 42: ['ub', 'ercot', 'legal', 'credit', 'head', 'houston', 'thursday', 'friday', 'i', 'ask'], 43: ['take', 'minut', '4', 'the', 'whole', 'process', 'long', 'averag', 'usual', '5'], 44: [], 45: ['cn', 'o', 'enron', 'ou', 'na', 'recipi', 'x', 'cc', 'neil', 'murray'], 46: ['x', 'to', 'michael', 'olsen', 'tom', 'acton', 'clem', 'cernosek', 'robert', 'cotten'], 47: [], 48: ['it', 'trade', 'deal', 'question', 'i', 'look', 'like', 'crosstimb', 'phys', 'us'], 49: ['i', 'here', 'bob', 'cotten', 'say', 'big', 'cowboy', 'think', 'tri', 'conoco'], 50: ['gepl', 'tom', 'purchas', 'conoc ...

# %%
# Search for similar authors
authors_similars = []
for auth1 in authors_list:
    for auth2 in authors_list[::-1]:
        if auth1 != auth2:
            intersection = list(set(top_words_list[auth1]) & set(top_words_list[auth2]))
            if len(intersection) >= 2:
                authors_similars.append((auth1, auth2, intersection))
print(authors_similars)
# Out:
# [(1, 97, ['x', 'to']), (1, 95, ['j', 'x', 'to']), (1, 93, ['x', 'to']), (1, 84, ['j', 'robert', 'to']), (1, 82, ['x', 'to']), (1, 77, ['x', 'to']), (1, 73, ['j', 'x', 'to']), (1, 46, ['cotten', 'robert', 'x', 'to']), (1, 33, ['x', 'to']), (1, 31, ['x', 'to']), (2, 92, ['deal', 'term']), (2, 50, ['deal', 'ticket']), (3, 81, ['flow', 'i']), (3, 32, ['flow', 'i']), (3, 4, ['i', 'april']), (4, 32, ['take', 'i']), (4, 3, ['i', 'april']), (5, 97, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (5, 85, ['enron', 'cn', 'na', 'hou', 'ou', 'recipi', 'o']), (5, 84, ['enron', 'hou']), (5, 77, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (5, 55, ['enron', 'recipi']), (5, 45, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (5, 33, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (5, 31, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (6, 94, ['the', 'meter']), (7, 89, ['question', 'call', 'i']), (7, 48, ['deal', 'question', 'i', 'look']), (7, 21, ['deal', 'i']), (7, 16, ['deal', 'i']), (7, 15, ['deal', 'i']), (8, 90, ['purchas', 'price']), (9, 16, ['deal', 'ena', 'the']), (10, 74, ['want', 'i']), (10, 21, ['daren', 'i']), (12, 69, ['know', 'i', 'list']), (12, 64, ['get', 'i']), (12, 39, ['i', 'tenaska']), (12, 29, ['i', 'agreement']), (12, 17, ['get', 'assign']), (12, 13, ['get', 'i']), (13, 78, ['monday', 'i']), (13, 69, ['i', 'email']), (13, 64, ['get', 'i']), (13, 39, ['i', 'need']), (13, 35, ['i', 'need']), (13, 32, ['put', 'i']), (13, 12, ['get', 'i']), (14, 92, ['deal', 'gas']), (14, 90, ['gas', 'price']), (14, 59, ['pleas', 'confirm']), (14, 58, ['txu', 'confirm']), (14, 15, ['deal', 'show']), (15, 48, ['deal', 'i']), (15, 21, ['deal', 'i']), (15, 16, ['deal', 'i']), (15, 14, ['deal', 'show']), (15, 7, ['deal', 'i']), (16, 48, ['deal', 'i']), (16, 39, ['6', 'i']), (16, 29, ['i', 'anyth']), (16, 21, ['deal', 'i']), (16, 15, ['deal', 'i']), (16, 9, ['deal', 'ena', 'the']), (16, 7, ['deal', 'i']), (17, 12, ['get', 'assign']), (21, 87, ['deal', 'daren', '01']), (21, 78, ['i', 'it']), (21, 48, ['deal', 'i', 'it']), (21, 42, ['i', 'ask']), (21, 39, ['i', '01']), (21, 32, ['i', 'it']), (21, 16, ['deal', 'i']), (21, 15, ['deal', 'i']), (21, 10, ['daren', 'i']), (21, 7, ['deal', 'i']), (22, 81, ['hgpl', 'meter']), (22, 56, ['1', 'oper']), (24, 89, ['inform', 'pleas']), (24, 80, ['send', 'pleas']), (24, 59, ['send', 'pleas']), (24, 35, ['we', 'need']), (25, 91, ['mailto', 'enron', 'com', 'imceanot']), (25, 54, ['enron', 'com']), (26, 93, ['b', 'camp', 'howard', 'x']), (26, 45, ['cc', 'x']), (26, 28, ['cc', 'x']), (27, 65, ['would', 'like']), (27, 37, ['would', 'like']), (28, 95, ['gari', 'x']), (28, 73, ['x', 'jame']), (28, 45, ['cc', 'x']), (28, 26, ['cc', 'x']), (29, 16, ['i', 'anyth']), (29, 12, ['i', 'agreement']), (30, 37, ['as', 'discuss']), (31, 97, ['cn', 'enron', 'na', 'x', 'to', 'ou', 'recipi', 'o']), (31, 95, ['x', 'to']), (31, 93, ['x', 'to']), (31, 85, ['enron', 'cn', 'na', 'recipi', 'ou', 'o']), (31, 84, ['enron', 'to']), (31, 82, ['x', 'to']), (31, 77, ['cn', 'enron', 'na', 'x', 'to', 'ou', 'recipi', 'o']), (31, 73, ['x', 'to']), (31, 55, ['enron', 'recipi']), (31, 46, ['x', 'to']), (31, 45, ['cn', 'enron', 'na', 'x', 'ou', 'recipi', 'o']), (31, 33, ['cn', 'enron', 'na', 'x', 'to', 'ou', 'recipi', 'o']), (31, 5, ['cn', 'enron', 'na', 'recipi', 'ou', 'o']), (31, 1, ['x', 'to']), (32, 81, ['flow', 'i']), (32, 78, ['i', 'it']), (32, 48, ['i', 'it']), (32, 43, ['take', 'usual']), (32, 42, ['i', 'ercot']), (32, 39, ['week', 'i']), (32, 21, ['i', 'it']), (32, 13, ['put', 'i']), (32, 4, ['take', 'i']), (32, 3, ['flow', 'i']), (33, 97, ['cn', 'enron', 'na', 'x', 'to', 'ou', 'recipi', 'o']), (33, 95, ['x', 'to']), (33, 93, ['x', 'to']), (33, 85, ['enron', 'cn', 'na', 'recipi', 'ou', 'o']), (33, 84, ['enron', 'to']), (33, 82, ['x', 'to']), (33, 77, ['cn', 'enron', 'na', 'x', 'to', 'ou', 'recipi', 'o']), (33, 73, ['x', 'to']), (33, 55, ['enron', 'recipi']), (33, 46, ['x', 'to']), (33, 45, ['cn', 'enron', 'na', 'x', 'ou', 'recipi', 'o']), (33, 31, ['cn' ...

# %%
lists_similar_authors = [[] for i in range(len(authors_list))] 
i = 0
for author in authors_list:
    l = [a_tuple[1] for a_tuple in authors_similars if a_tuple[0] == author] ## lista di autori simili per l'autore "author"
    if l: 
        lists_similar_authors[i] = [author] + [l]
    else:
        lists_similar_authors[i] = [author]
    i += 1

column_labels=[ "author","similar authors"]
df=pd.DataFrame(lists_similar_authors,columns=column_labels)
df[:]
# Out:
#     author                                    similar authors
# 0        1           [97, 95, 93, 84, 82, 77, 73, 46, 33, 31]
# 1        2                                           [92, 50]
# 2        3                                        [81, 32, 4]
# 3        4                                            [32, 3]
# 4        5                   [97, 85, 84, 77, 55, 45, 33, 31]
# ..     ...                                                ...
# 92      93            [97, 95, 82, 77, 73, 46, 33, 31, 26, 1]
# 93      94                                                [6]
# 94      95  [97, 93, 87, 85, 84, 82, 77, 73, 46, 33, 31, 2...
# 95      96                                               None
# 96      97  [95, 93, 85, 84, 82, 77, 73, 71, 55, 52, 46, 4...
#
# [97 rows x 2 columns]
